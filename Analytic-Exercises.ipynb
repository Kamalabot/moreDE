# %%
import configparser
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
config = configparser.ConfigParser()
config.read('calter.config')
# Out:
# ['calter.config']

# %%
db = config['POSTGRES']['PG_DB']
retail_db = config['POSTGRES']['PG_ret']
hr_db = config['POSTGRES']['PG_hr']
user = config['POSTGRES']['PG_UNAME']
passwd = config['POSTGRES']['PG_PASS']
port = config['POSTGRES']['PG_PORT']
host = config['POSTGRES']['PG_HOST']

# %%
hr_db
# Out:
# 'hr_db'

# %%
credentials = "postgresql://{}:{}@{}:{}/{}".format(user,passwd,host,port,db)

# %%
credentials_ret = "postgresql://{}:{}@{}:{}/{}".format(user,passwd,host,port,retail_db)
credentials_hr = "postgresql://{}:{}@{}:{}/{}".format(user,passwd,host,port,hr_db)

# %%
#using psycopg2 to test connection since there are no tables
import psycopg2
try:
    conn = psycopg2.connect(host=host,dbname=db,user=user,password=passwd,port=port)
except Exception as e:
    print(e)
    
conn.set_session(autocommit=True)

try:
    cur = conn.cursor()
    
except:
    print(e)

# %%
#using psycopg2 to test connection since there are no tables
import psycopg2
try:
    conn_hr = psycopg2.connect(host=host,dbname=hr_db,user=user,password=passwd,port=port)
except Exception as e:
    print(e)
    
conn_hr.set_session(autocommit=True)

try:
    cur = conn_hr.cursor()
    
except:
    print(e)

# %%
credentials_hr
# Out:
# 'postgresql://postgres:1234@localhost:5432/hr_db'

# %%
#Helper functions to work with the database
def schemaGen(dataframe, schemaName):
    localSchema = pd.io.sql.get_schema(dataframe,schemaName)
    localSchema = localSchema.replace('TEXT','VARCHAR(255)').replace('INTEGER','NUMERIC').replace('\n','').replace('"',"")
    return "".join(localSchema)

#Using pandas read_sql for getting schema
def getSchema(tableName, credentials):
    schema = pd.read_sql("""SELECT * FROM information_schema.columns where table_name='{}'""".format(tableName),con=credentials)
    return schema

#Issue is in using pd.read_sql to write data to the database. so using psycopg2
def queryTable(query):
    try:
        schema = cur.execute(query)
        return 
    except Exception as e:
        print(e)
        
#This doesn't return anything

#Using the pd.read_sql for getting data from db
def queryBase(query):
    requiredTable = pd.read_sql(query,con=credentials)
    return requiredTable

def queryBasehr(query):
    requiredTable = pd.read_sql(query,con=credentials_hr)
    return requiredTable

#This returns the dataframe

# %%
queryBasehr("""SELECT * FROM employees LIMIT 5""")
# Out:
#    employee_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  1987-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 4          104      Bruce     Ernst    BERNST  590.423.4568  1991-05-21
#
#     job_id   salary commission_pct  manager_id  department_id
# 0  AD_PRES  24000.0           None         NaN             90
# 1    AD_VP  17000.0           None       100.0             90
# 2    AD_VP  17000.0           None       100.0             90
# 3  IT_PROG   9000.0           None       102.0             60
# 4  IT_PROG   6000.0           None       103.0             60

# %%
queryBasehr("""SELECT * FROM departments LIMIT 5""")
# Out:
#    department_id       department_name manager_id  location_id
# 0            120              Treasury       None         1700
# 1            130         Corporate Tax       None         1700
# 2            140    Control And Credit       None         1700
# 3            150  Shareholder Services       None         1700
# 4            160              Benefits       None         1700

# %%
queryBasehr("""SELECT e.employee_id, e.department_id, e.salary,
                d.department_name
               FROM employees e 
               LEFT OUTER JOIN departments d
               ON e.department_id = d.department_id
               LIMIT 2""")
# Out:
#    employee_id  department_id   salary department_name
# 0          100             90  24000.0       Executive
# 1          101             90  17000.0       Executive

# %%
queryBasehr("""SELECT e.department_id,
                ae.avg_dept_salary,
                e.salary, e.employee_id, d.department_name
               FROM employees e 
               LEFT OUTER JOIN (
                   SELECT department_id, 
                   ROUND(AVG(salary)::numeric,2) AS avg_dept_salary
                   FROM employees
                   GROUP BY department_id
                   ) ae
               ON e.department_id = ae.department_id
               JOIN departments d
               ON ae.department_id = d.department_id
               WHERE e.salary > avg_dept_salary
               ORDER BY d.department_id,e.salary DESC""")
# Out:
#     department_id  avg_dept_salary   salary  employee_id department_name
# 0              20          9500.00  13000.0          201       Marketing
# 1              30          4150.00  11000.0          114      Purchasing
# 2              50          3475.56   8200.0          121        Shipping
# 3              50          3475.56   8000.0          120        Shipping
# 4              50          3475.56   7900.0          122        Shipping
# 5              50          3475.56   6500.0          123        Shipping
# 6              50          3475.56   5800.0          124        Shipping
# 7              50          3475.56   4200.0          184        Shipping
# 8              50          3475.56   4100.0          185        Shipping
# 9              50          3475.56   4000.0          192        Shipping
# 10             50          3475.56   3900.0          193        Shipping
# 11             50          3475.56   3800.0          188        Shipping
# 12             50          3475.56   3600.0          189        Shipping
# 13             50          3475.56   3600.0          137        Shipping
# 14             50          3475.56   3500.0          141        Shipping
# 15             60          5760.00   9000.0          103              IT
# 16             60          5760.00   6000.0          104              IT
# 17             80          8955.88  14000.0          145           Sales
# 18             80          8955.88  13500.0          146           Sales
# 19             80          8955.88  12000.0          147           Sales
# 20             80          8955.88  11500.0          168           Sales
# 21             80          8955.88  11000.0          174           Sales
# 22             80          8955.88  11000.0          148           Sales
# 23             80          8955.88  10500.0          149           Sales
# 24             80          8955.88  10500.0          162           Sales
# 25             80          8955.88  10000.0          156           Sales
# 26             80          8955.88  10000.0          169           Sales
# 27             80          8955.88  10000.0          150           Sales
# 28             80          8955.88   9600.0          170           Sales
# 29             80          8955.88   9500.0          163           Sales
# 30             80          8955.88   9500.0          151           Sales
# 31             80          8955.88   9500.0          157           Sales
# 32             80          8955.88   9000.0          152           Sales
# 33             80          8955.88   9000.0          158           Sales
# 34             90         19333.33  24000.0          100       Executive
# 35            100          8600.00  12000.0          108         Finance
# 36            100          8600.00   9000.0          109         Finance
# 37            110         10150.00  12000.0          205      Accounting

# %%
#Using windowing function

queryBasehr("""SELECT e.employee_id, e.department_id, e.salary,
    AVG(e.salary) OVER (
        PARTITION BY e.department_id
    ) AS department_salary_expense
FROM employees e 
ORDER BY e.department_id, e.salary DESC""")
# Out:
#      employee_id  department_id   salary  department_salary_expense
# 0            200           10.0   4400.0                     4400.0
# 1            201           20.0  13000.0                     9500.0
# 2            202           20.0   6000.0                     9500.0
# 3            114           30.0  11000.0                     4150.0
# 4            115           30.0   3100.0                     4150.0
# ..           ...            ...      ...                        ...
# 102          111          100.0   7700.0                     8600.0
# 103          113          100.0   6900.0                     8600.0
# 104          205          110.0  12000.0                    10150.0
# 105          206          110.0   8300.0                    10150.0
# 106          178            NaN   7000.0                     7000.0
#
# [107 rows x 4 columns]

# %%
queryBasehr("""SELECT t.employee_id, t.department_id, t.salary,
            d.department_name,
            ROUND(SUM(t.salary) OVER(
            PARTITION BY t.department_id
            ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW),2)
            AS cumulative_dept_salary
            FROM employees t
            LEFT OUTER JOIN departments d 
            ON t.department_id = d.department_id
            WHERE d.department_name IN ('Finance','IT')""")
# Out:
#     employee_id  department_id   salary department_name  \
# 0           103             60   9000.0              IT
# 1           104             60   6000.0              IT
# 2           105             60   4800.0              IT
# 3           106             60   4800.0              IT
# 4           107             60   4200.0              IT
# 5           108            100  12000.0         Finance
# 6           109            100   9000.0         Finance
# 7           110            100   8200.0         Finance
# 8           111            100   7700.0         Finance
# 9           112            100   7800.0         Finance
# 10          113            100   6900.0         Finance
#
#     cumulative_dept_salary
# 0                   9000.0
# 1                  15000.0
# 2                  19800.0
# 3                  24600.0
# 4                  28800.0
# 5                  12000.0
# 6                  21000.0
# 7                  29200.0
# 8                  36900.0
# 9                  44700.0
# 10                 51600.0

# %%
queryBase("""SELECT t.*,
    round(sum(t.revenue) OVER (
        ORDER BY order_date
        ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
    ), 2) AS moving_3day_revenue
FROM daily_revenue t
ORDER BY order_date
LIMIT 20""")
# Out:
#    order_date   revenue  moving_3day_revenue
# 0  2013-07-25  31547.23             31547.23
# 1  2013-07-26  54713.23             86260.46
# 2  2013-07-27  48411.48            134671.94
# 3  2013-07-28  35672.03            138796.74
# 4  2013-07-29  54579.70            138663.21
# 5  2013-07-30  49329.29            139581.02
# 6  2013-07-31  59212.49            163121.48
# 7  2013-08-01  49160.08            157701.86
# 8  2013-08-02  50688.58            159061.15
# 9  2013-08-03  43416.74            143265.40
# 10 2013-08-04  35093.01            129198.33
# 11 2013-08-05  34025.27            112535.02
# 12 2013-08-06  57843.89            126962.17
# 13 2013-08-07  45525.59            137394.75
# 14 2013-08-08  33549.47            136918.95
# 15 2013-08-09  29225.16            108300.22
# 16 2013-08-10  46435.04            109209.67
# 17 2013-08-11  31155.50            106815.70
# 18 2013-08-12  59014.74            136605.28
# 19 2013-08-13  17956.88            108127.12

# %%
queryBasehr("""SELECT e.employee_id, e.department_id,
                d.department_name, e.salary,
                dense_rank() OVER(
                PARTITION BY e.department_id
                ORDER BY salary DESC
                ) AS d_rank
                FROM employees e 
                JOIN departments d 
                ON e.department_id = d.department_id
                LIMIT 5""")
# Out:
#    employee_id  department_id department_name   salary  d_rank
# 0          200             10  Administration   4400.0       1
# 1          201             20       Marketing  13000.0       1
# 2          202             20       Marketing   6000.0       2
# 3          114             30      Purchasing  11000.0       1
# 4          115             30      Purchasing   3100.0       2

# %%
queryBase("""SELECT * FROM order_items LIMIT 5""")
# Out:
#    order_item_id  order_item_order_id  order_item_product_id  \
# 0              1                    1                    957
# 1              2                    2                   1073
# 2              3                    2                    502
# 3              4                    2                    403
# 4              5                    4                    897
#
#    order_item_quantity  order_item_subtotal  order_item_product_price
# 0                    1               299.98                    299.98
# 1                    1               199.99                    199.99
# 2                    5               250.00                     50.00
# 3                    1               129.99                    129.99
# 4                    2                49.98                     24.99

# %%
queryBase("""SELECT o.order_status, pdt.product_name,
            oi.order_item_subtotal 
            FROM orders o
            JOIN order_items oi
            ON o.order_id = oi.order_item_order_id
            JOIN products pdt
            ON oi.order_item_product_id = pdt.product_id
            LIMIT 5""")
# Out:
#       order_status                                   product_name  \
# 0           CLOSED  Diamondback Women's Serene Classic Comfort Bi
# 1  PENDING_PAYMENT                    Pelican Sunstream 100 Kayak
# 2  PENDING_PAYMENT           Nike Men's Dri-FIT Victory Golf Polo
# 3  PENDING_PAYMENT        Nike Men's CJ Elite 2 TD Football Cleat
# 4           CLOSED     Team Golf New England Patriots Putter Grip
#
#    order_item_subtotal
# 0               299.98
# 1               199.99
# 2               250.00
# 3               129.99
# 4                49.98

# %%
queryBase("""SELECT o.order_status,pdt.product_id, pdt.product_name,
            o.order_date,
            SUM(oi.order_item_subtotal) OVER(
            PARTITION BY oi.order_item_product_id
            ) AS revenue,
            rank() OVER(
            PARTITION BY oi.order_item_product_id
            ) AS product_rank
            FROM orders o
            JOIN order_items oi
            ON o.order_id = oi.order_item_order_id
            JOIN products pdt
            ON oi.order_item_product_id = pdt.product_id
            WHERE o.order_status IN ('CLOSED','COMPLETE')
            LIMIT 5""")
# Out:
#   order_status  product_id                             product_name  \
# 0       CLOSED          19  Nike Men's Fingertrap Max Training Shoe
# 1       CLOSED          19  Nike Men's Fingertrap Max Training Shoe
# 2     COMPLETE          19  Nike Men's Fingertrap Max Training Shoe
# 3     COMPLETE          19  Nike Men's Fingertrap Max Training Shoe
# 4     COMPLETE          19  Nike Men's Fingertrap Max Training Shoe
#
#   order_date  revenue  product_rank
# 0 2013-08-04  2999.76             1
# 1 2013-08-30  2999.76             1
# 2 2013-09-22  2999.76             1
# 3 2013-10-13  2999.76             1
# 4 2013-10-14  2999.76             1

# %%
queryBase("""SELECT sup.product_id, sup.product_name,
            SUM(sup.revenue) AS revenue
            FROM (
            SELECT o.order_status,pdt.product_id, pdt.product_name,
            o.order_date,
            SUM(oi.order_item_subtotal) OVER(
                PARTITION BY oi.order_item_product_id
            ) AS revenue
            FROM orders o
                JOIN order_items oi
                ON o.order_id = oi.order_item_order_id
                JOIN products pdt
                ON oi.order_item_product_id = pdt.product_id
            WHERE o.order_status IN ('CLOSED','COMPLETE') AND
            TO_CHAR(o.order_date,'yyyy-MM')='2014-01'
            )sup
            GROUP BY sup.product_name, sup.product_id
            ORDER BY revenue DESC
            LIMIT 15""")
# Out:
#     product_id                                   product_name       revenue
# 0         1004      Field & Stream Sportsman 16 Gun Fire Safe  1.572437e+08
# 1          365               Perfect Fitness Perfect Rip Deck  1.325404e+08
# 2          403        Nike Men's CJ Elite 2 TD Football Cleat  8.911906e+07
# 3          502           Nike Men's Dri-FIT Victory Golf Polo  8.874040e+07
# 4          957  Diamondback Women's Serene Classic Comfort Bi  7.320592e+07
# 5         1014               O'Brien Men's Neoprene Life Vest  6.790978e+07
# 6         1073                    Pelican Sunstream 100 Kayak  6.406800e+07
# 7          191              Nike Men's Free 5.0+ Running Shoe  5.966133e+07
# 8          627  Under Armour Girls' Toddler Spine Surge Runni  1.306173e+07
# 9          565  adidas Youth Germany Black/Red Away Match Soc  6.160000e+04
# 10         249  Under Armour Women's Micro G Skulpt Running S  3.287206e+04
# 11         771                      Clicgear Rovic Cooler Bag  2.943264e+04
# 12          44     adidas Men's F10 Messi TRX FG Soccer Cleat  2.591568e+04
# 13         564  Nike Men's Deutschland Weltmeister Winners Bl  2.385000e+04
# 14         818                    Titleist Pro V1x Golf Balls  2.361108e+04

# %%
queryTable("""DROP TABLE IF EXISTS jansales""")

# %%
queryTable("""CREATE TABLE janSales
                AS
                SELECT o.order_status,pdt.product_id, 
                    pdt.product_name,pdt.product_category_id,
                    o.order_date,
                    SUM(oi.order_item_subtotal) OVER(
                        PARTITION BY oi.order_item_product_id
                    ) AS revenue
                    FROM orders o
                        JOIN order_items oi
                        ON o.order_id = oi.order_item_order_id
                        JOIN products pdt
                        ON oi.order_item_product_id = pdt.product_id
                    WHERE o.order_status IN ('CLOSED','COMPLETE') AND
                    TO_CHAR(o.order_date,'yyyy-MM')='2014-01'""")

# %%
queryBase("""SELECT * FROM jansales LIMIT 5""")
# Out:
#   order_status  product_id                             product_name  \
# 0     COMPLETE          19  Nike Men's Fingertrap Max Training Shoe
# 1     COMPLETE          19  Nike Men's Fingertrap Max Training Shoe
# 2     COMPLETE          19  Nike Men's Fingertrap Max Training Shoe
# 3     COMPLETE          24              Elevation Training Mask 2.0
# 4     COMPLETE          24              Elevation Training Mask 2.0
#
#    product_category_id order_date  revenue
# 0                    2 2014-01-16   374.97
# 1                    2 2014-01-22   374.97
# 2                    2 2014-01-22   374.97
# 3                    2 2014-01-27   719.91
# 4                    2 2014-01-11   719.91

# %%
queryBase("""SELECT categ.category_id, categ.category_name, 
            j.product_id, j.product_name, j.revenue
            FROM jansales j
            JOIN categories categ
            ON j.product_category_id = categ.category_id
            LIMIT 5;""")
# Out:
#    category_id category_name  product_id  \
# 0            2        Soccer          19
# 1            2        Soccer          19
# 2            2        Soccer          19
# 3            2        Soccer          24
# 4            2        Soccer          24
#
#                               product_name  revenue
# 0  Nike Men's Fingertrap Max Training Shoe   374.97
# 1  Nike Men's Fingertrap Max Training Shoe   374.97
# 2  Nike Men's Fingertrap Max Training Shoe   374.97
# 3              Elevation Training Mask 2.0   719.91
# 4              Elevation Training Mask 2.0   719.91

# %%
queryBase("""SELECT categ.category_id, categ.category_name, 
            j.product_id, j.product_name, SUM(j.revenue) as revenue
            FROM jansales j
            JOIN categories categ
            ON j.product_category_id = categ.category_id
            GROUP BY categ.category_id, categ.category_name,
            j.product_id, j.product_name
            ORDER BY category_id, revenue DESC
            LIMIT 5;""")
# Out:
#    category_id        category_name  product_id  \
# 0            2               Soccer          24
# 1            2               Soccer          19
# 2            3  Baseball & Softball          44
# 3            3  Baseball & Softball          37
# 4            3  Baseball & Softball          35
#
#                                  product_name   revenue
# 0                 Elevation Training Mask 2.0   2879.64
# 1     Nike Men's Fingertrap Max Training Shoe   1124.91
# 2  adidas Men's F10 Messi TRX FG Soccer Cleat  25915.68
# 3       adidas Kids' F5 Messi FG Soccer Cleat   4408.74
# 4     adidas Brazuca 2014 Official Match Ball    639.96

# %%
queryBase("""SELECT category_id,category_name, 
            product_id,product_name,revenue,
            rank() OVER(
                PARTITION BY category_id
                ORDER BY revenue
            ) AS product_rank
            FROM(
                SELECT categ.category_id, categ.category_name, 
                j.product_id, j.product_name, SUM(j.revenue) as revenue
                FROM jansales j
                JOIN categories categ
                ON j.product_category_id = categ.category_id
                GROUP BY categ.category_id, categ.category_name,
                j.product_id, j.product_name
                ORDER BY category_id, revenue DESC
            ) s""")
# Out:
#     category_id         category_name  product_id  \
# 0             2                Soccer          19
# 1             2                Soccer          24
# 2             3   Baseball & Softball          35
# 3             3   Baseball & Softball          37
# 4             3   Baseball & Softball          44
# ..          ...                   ...         ...
# 91           44    Hunting & Shooting         977
# 92           45               Fishing        1004
# 93           46  Indoor/Outdoor Games        1014
# 94           48          Water Sports        1059
# 95           48          Water Sports        1073
#
#                                   product_name       revenue  product_rank
# 0      Nike Men's Fingertrap Max Training Shoe  1.124910e+03             1
# 1                  Elevation Training Mask 2.0  2.879640e+03             2
# 2      adidas Brazuca 2014 Official Match Ball  6.399600e+02             1
# 3        adidas Kids' F5 Messi FG Soccer Cleat  4.408740e+03             2
# 4   adidas Men's F10 Messi TRX FG Soccer Cleat  2.591568e+04             3
# ..                                         ...           ...           ...
# 91                    ENO Atlas Hammock Straps  1.481506e+04             3
# 92   Field & Stream Sportsman 16 Gun Fire Safe  1.572437e+08             1
# 93            O'Brien Men's Neoprene Life Vest  6.790978e+07             1
# 94                 Pelican Maverick 100X Kayak  3.499900e+02             1
# 95                 Pelican Sunstream 100 Kayak  6.406800e+07             2
#
# [96 rows x 6 columns]

# %%
(
)
