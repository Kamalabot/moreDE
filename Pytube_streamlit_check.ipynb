# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import pandas as pd
from scipy.interpolate import griddata
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/christopherpaine/MDD/main/Mortality_tables/HMD_UK_males_1x1.csv',header=0)
x, y, z = (np.array(df[df['Age']!='110+'][col], 
                    dtype=float) for col in ['Age', 'Year', 'qx'])
xi, yi = np.linspace(x.min(), x.max(), 100), np.linspace(y.min(), y.max(), 100)
X, Y = np.meshgrid(xi, yi)
Z = griddata((x,y),z,(X,Y), method='cubic')
fig = go.Figure(go.Surface(x=xi, y=yi, z=Z), 
                layout=dict(scene=dict(yaxis_type="log")))
fig.show()
# Out:
# <div>                            <div id="b3818320-cacb-45bf-a2bf-3bc7e3d4a7c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3818320-cacb-45bf-a2bf-3bc7e3d4a7c2")) {                    Plotly.newPlot(                        "b3818320-cacb-45bf-a2bf-3bc7e3d4a7c2",                        [{"x":[0.0,1.101010101010101,2.202020202020202,3.3030303030303028,4.404040404040404,5.505050505050505,6.6060606060606055,7.707070707070707,8.808080808080808,9.909090909090908,11.01010101010101,12.11111111111111,13.212121212121211,14.313131313131313,15.414141414141413,16.515151515151516,17.616161616161616,18.717171717171716,19.818181818181817,20.91919191919192,22.02020202020202,23.12121212121212,24.22222222222222,25.32323232323232,26.424242424242422,27.525252525252
# ...
