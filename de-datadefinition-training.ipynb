# %%
import configparser
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
config = configparser.ConfigParser()
config.read('clustertab.config')
# Out:
# ['clustertab.config']

# %%
db = config['POSTGRES']['PG_DB']
user = config['POSTGRES']['PG_UNAME']
passwd = config['POSTGRES']['PG_PASS']
port = config['POSTGRES']['PG_PORT']
host = config['POSTGRES']['PG_HOST']

# %%
db
# Out:
# 'retail_db'

# %%
credentials = "postgresql://{}:{}@{}:{}/{}".format(user,passwd,host,port,db)

#using psycopg2 to test connection since there are no tables
import psycopg2
try:
    conn = psycopg2.connect(host=host,dbname=db,user=user,password=passwd,port=port)
except Exception as e:
    print(e)
    
conn.set_session(autocommit=True)

try:
    cur = conn.cursor()
    
except:
    print(e)

# %%
credentials
# Out:
# 'postgresql://postgres:1234@172.17.0.2:5432/retail_db'

# %%
#Helper functions to work with the database
def schemaGen(dataframe, schemaName):
    localSchema = pd.io.sql.get_schema(dataframe,schemaName)
    localSchema = localSchema.replace('TEXT','VARCHAR(255)').replace('INTEGER','NUMERIC').replace('\n','').replace('"',"")
    return "".join(localSchema)

#Using pandas read_sql for getting schema
def getSchema(tableName, credentials):
    schema = pd.read_sql("""SELECT table_catalog, table_name, 
                column_name, data_type, 
                ordinal_position, column_default, character_maximum_length,
                is_nullable FROM information_schema.columns where table_name='{}'""".format(tableName),con=credentials)
    return schema

#Issue is in using pd.read_sql to write data to the database. so using psycopg2
def queryTable(query):
    try:
        schema = cur.execute(query)
        return 
    except Exception as e:
        print(e)
        
#This doesn't return anything

#Using the pd.read_sql for getting data from db
def queryBase(query):
    requiredTable = pd.read_sql(query,con=credentials)
    return requiredTable

#This returns the dataframe

# %% [markdown]
# **Data Definition** is kept seperately from the **DQL (Data Query)** and **DML (Data Manipulation)** Languages, or clauses.
#
# DDL tasks are
#
# - Creating Tables : Objects inside the database
#
# - Creating Indexes for Performance increase
#
# - Creating Constraint (NOT NULL, CHECK, PRIMARY KEY, UNIQUE etc)
#
# Another important command is ALTER. Helps in Adding Columns, Dropping and Changing datatypes
#
# Less known operation is adding comments on Table and Column levels.

# %%
queryBase("""CREATE TABLE users ( 
    user_id SERIAL PRIMARY KEY,
    user_first_name VARCHAR(30) NOT NULL,
    user_last_name VARCHAR(30) NOT NULL,
    user_email_id VARCHAR(50) NOT NULL,
    user_email_validated BOOLEAN DEFAULT FALSE,
    user_password VARCHAR(200),
    user_role VARCHAR(1) NOT NULL DEFAULT 'U', --U and A
    is_active BOOLEAN DEFAULT FALSE,
    created_dt DATE DEFAULT CURRENT_DATE,
    last_updated_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);""")
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 queryBase("""CREATE TABLE users (
#       2     user_id SERIAL PRIMARY KEY,
#       3     user_first_name VARCHAR(30) NOT NULL,
#       4     user_last_name VARCHAR(30) NOT NULL,
#       5     user_email_id VARCHAR(50) NOT NULL,
#       6     user_email_validated BOOLEAN DEFAULT FALSE,
#       7     user_password VARCHAR(200),
#       8     user_role VARCHAR(1) NOT NULL DEFAULT 'U', --U and A
#       9     is_active BOOLEAN DEFAULT FALSE,
#      10     created_dt DATE DEFAULT CURRENT_DATE,
#      11     last_updated_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP
#      12 );""")
#
# Cell In [7], line 24, in queryBase(query)
#      23 def queryBase(query):
# ---> 24     requiredTable = pd.read_sql(query,con=credentials)
#      25     return requiredTable
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:1574, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1564     return self._query_iterator(
#    1565         result,
#    1566         chunksize,
#    (...)
#    1571         dtype=dtype,
#    1572     )
#    1573 else:
# -> 1574     data = result.fetchall()
#    1575     frame = _wrap_result(
#    1576         data,
#    1577         columns,
#    (...)
#    1581         dtype=dtype,
#    1582     )
#    1583     return frame
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/result.py:1058, in Result.fetchall(self)
#    1055 def fetchall(self):
#    1056     """A synonym for the :meth:`_engine.Result.all` method."""
# -> 1058     return self._allrows()
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/result.py:399, in ResultInternal._allrows(self)
#     395 def _allrows(self):
#     397     post_creational_filter = self._post_creational_filter
# --> 399     make_row = self._row_getter
#     401     rows = self._fetchall_impl()
#     402     if make_row:
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:1184, in HasMemoized.memoized_attribute.__get__(self, obj, cls)
#    1182 if obj is None:
#    1183     return self
# -> 1184 obj.__dict__[self.__name__] = result = self.fget(obj)
#    1185 obj._memoized_keys |= {self.__name__}
#    1186 return result
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/result.py:320, in ResultInternal._row_getter(self)
#     317 key_style = real_result._process_row._default_key_style
#     318 metadata = self._metadata
# --> 320 keymap = metadata._keymap
#     321 processors = metadata._processors
#     322 tf = metadata._tuplefilter
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/cursor.py:1221, in _NoResultMetaData._keymap(self)
#    1219 @property
#    1220 def _keymap(self):
# -> 1221     self._we_dont_return_rows()
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/cursor.py:1202, in _NoResultMetaData._we_dont_return_rows(self, err)
#    1201 def _we_dont_return_rows(self, err=None):
# -> 1202     util.raise_(
#    1203         exc.ResourceClosedError(
#    1204             "This result object does not return rows. "
#    1205             "It has been closed automatically."
#    1206         ),
#    1207         replace_context=err,
#    1208     )
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
#dropping the above table to create the same table differently

queryTable("""DROP TABLE users""")

# %%
queryTable("""CREATE TABLE users ( 
    user_id INT,
    user_first_name VARCHAR(30) NOT NULL,
    user_last_name VARCHAR(30) NOT NULL,
    user_email_id VARCHAR(50) NOT NULL,
    user_email_validated BOOLEAN,
    user_password VARCHAR(200),
    user_role VARCHAR(1),
    is_active BOOLEAN,
    created_dt DATE DEFAULT CURRENT_DATE
);""")

# %%
queryTable("""COMMENT ON TABLE users IS 'The table stores the user data'""")

# %%
queryBase("""SELECT table_catalog, table_name, 
                column_name, data_type, 
                ordinal_position, column_default, charact er_maximum_length,
                is_nullable FROM information_schema.columns WHERE table_name = 'users'
            ORDER BY ordinal_position""")
# Out:
#   table_catalog table_name           column_name          data_type  \
# 0     retail_db      users               user_id            integer
# 1     retail_db      users       user_first_name  character varying
# 2     retail_db      users        user_last_name  character varying
# 3     retail_db      users         user_email_id  character varying
# 4     retail_db      users  user_email_validated            boolean
# 5     retail_db      users         user_password  character varying
# 6     retail_db      users             user_role  character varying
# 7     retail_db      users             is_active            boolean
# 8     retail_db      users            created_dt               date
#
#    ordinal_position column_default  character_maximum_length is_nullable
# 0                 1           None                       NaN         YES
# 1                 2           None                      30.0          NO
# 2                 3           None                      30.0          NO
# 3                 4           None                      50.0          NO
# 4                 5           None                       NaN         YES
# 5                 6           None                     200.0         YES
# 6                 7           None                       1.0         YES
# 7                 8           None                       NaN         YES
# 8                 9   CURRENT_DATE                       NaN         YES

# %%
queryTable("""DROP SEQUENCE IF EXISTS users_user_id_seq""")

# %%
queryTable("""CREATE SEQUENCE users_user_id_seq""")

# %%
getSchema("users",credentials)
# Out:
#   table_catalog table_name           column_name          data_type  \
# 0     retail_db      users            created_dt               date
# 1     retail_db      users  user_email_validated            boolean
# 2     retail_db      users             is_active            boolean
# 3     retail_db      users               user_id            integer
# 4     retail_db      users             user_role  character varying
# 5     retail_db      users         user_password  character varying
# 6     retail_db      users       user_first_name  character varying
# 7     retail_db      users        user_last_name  character varying
# 8     retail_db      users         user_email_id  character varying
#
#    ordinal_position column_default  character_maximum_length is_nullable
# 0                 9   CURRENT_DATE                       NaN         YES
# 1                 5           None                       NaN         YES
# 2                 8           None                       NaN         YES
# 3                 1           None                       NaN         YES
# 4                 7           None                       1.0         YES
# 5                 6           None                     200.0         YES
# 6                 2           None                      30.0          NO
# 7                 3           None                      30.0          NO
# 8                 4           None                      50.0          NO

# %%
queryTable("""ALTER TABLE users ALTER COLUMN user_id SET DEFAULT nextval('users_user_id_seq')""")

# %%
getSchema("users",credentials)
# Out:
#   table_catalog table_name           column_name          data_type  \
# 0     retail_db      users            created_dt               date
# 1     retail_db      users  user_email_validated            boolean
# 2     retail_db      users             is_active            boolean
# 3     retail_db      users               user_id            integer
# 4     retail_db      users             user_role  character varying
# 5     retail_db      users         user_password  character varying
# 6     retail_db      users       user_first_name  character varying
# 7     retail_db      users        user_last_name  character varying
# 8     retail_db      users         user_email_id  character varying
#
#    ordinal_position                          column_default  \
# 0                 9                            CURRENT_DATE
# 1                 5                                    None
# 2                 8                                    None
# 3                 1  nextval('users_user_id_seq'::regclass)
# 4                 7                                    None
# 5                 6                                    None
# 6                 2                                    None
# 7                 3                                    None
# 8                 4                                    None
#
#    character_maximum_length is_nullable
# 0                       NaN         YES
# 1                       NaN         YES
# 2                       NaN         YES
# 3                       NaN         YES
# 4                       1.0         YES
# 5                     200.0         YES
# 6                      30.0          NO
# 7                      30.0          NO
# 8                      50.0          NO

# %%
queryTable("""ALTER TABLE users ALTER COLUMN user_email_validated SET DEFAULT FALSE""")

# %%
queryTable("""ALTER TABLE users ALTER COLUMN is_active SET DEFAULT FALSE""")

# %%
getSchema("users",credentials)
# Out:
#   table_catalog table_name           column_name          data_type  \
# 0     retail_db      users            created_dt               date
# 1     retail_db      users  user_email_validated            boolean
# 2     retail_db      users             is_active            boolean
# 3     retail_db      users               user_id            integer
# 4     retail_db      users             user_role  character varying
# 5     retail_db      users         user_password  character varying
# 6     retail_db      users       user_first_name  character varying
# 7     retail_db      users        user_last_name  character varying
# 8     retail_db      users         user_email_id  character varying
#
#    ordinal_position                          column_default  \
# 0                 9                            CURRENT_DATE
# 1                 5                                   false
# 2                 8                                   false
# 3                 1  nextval('users_user_id_seq'::regclass)
# 4                 7                                    None
# 5                 6                                    None
# 6                 2                                    None
# 7                 3                                    None
# 8                 4                                    None
#
#    character_maximum_length is_nullable
# 0                       NaN         YES
# 1                       NaN         YES
# 2                       NaN         YES
# 3                       NaN         YES
# 4                       1.0         YES
# 5                     200.0         YES
# 6                      30.0          NO
# 7                      30.0          NO
# 8                      50.0          NO

# %%
queryTable("""ALTER TABLE users ALTER COLUMN user_role SET DATA TYPE CHAR(1)""")

# %%
queryTable("""ALTER TABLE users ALTER COLUMN user_role SET DEFAULT 'U'""")

# %%
getSchema("users",credentials)
# Out:
#   table_catalog table_name           column_name          data_type  \
# 0     retail_db      users            created_dt               date
# 1     retail_db      users  user_email_validated            boolean
# 2     retail_db      users             is_active            boolean
# 3     retail_db      users               user_id            integer
# 4     retail_db      users             user_role          character
# 5     retail_db      users         user_password  character varying
# 6     retail_db      users       user_first_name  character varying
# 7     retail_db      users        user_last_name  character varying
# 8     retail_db      users         user_email_id  character varying
#
#    ordinal_position                          column_default  \
# 0                 9                            CURRENT_DATE
# 1                 5                                   false
# 2                 8                                   false
# 3                 1  nextval('users_user_id_seq'::regclass)
# 4                 7                             'U'::bpchar
# 5                 6                                    None
# 6                 2                                    None
# 7                 3                                    None
# 8                 4                                    None
#
#    character_maximum_length is_nullable
# 0                       NaN         YES
# 1                       NaN         YES
# 2                       NaN         YES
# 3                       NaN         YES
# 4                       1.0         YES
# 5                     200.0         YES
# 6                      30.0          NO
# 7                      30.0          NO
# 8                      50.0          NO

# %%
queryTable("""ALTER TABLE users ADD COLUMN last_updated_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP""")

# %%
getSchema('users',credentials)
# Out:
#   table_catalog table_name           column_name                    data_type  \
# 0     retail_db      users               user_id                      integer
# 1     retail_db      users  user_email_validated                      boolean
# 2     retail_db      users             is_active                      boolean
# 3     retail_db      users            created_dt                         date
# 4     retail_db      users       last_updated_ts  timestamp without time zone
# 5     retail_db      users         user_password            character varying
# 6     retail_db      users       user_first_name            character varying
# 7     retail_db      users        user_last_name            character varying
# 8     retail_db      users         user_email_id            character varying
# 9     retail_db      users             user_role                    character
#
#    ordinal_position                          column_default  \
# 0                 1  nextval('users_user_id_seq'::regclass)
# 1                 5                                   false
# 2                 8                                   false
# 3                 9                            CURRENT_DATE
# 4                10                       CURRENT_TIMESTAMP
# 5                 6                                    None
# 6                 2                                    None
# 7                 3                                    None
# 8                 4                                    None
# 9                 7                             'U'::bpchar
#
#    character_maximum_length is_nullable
# 0                       NaN         YES
# 1                       NaN         YES
# 2                       NaN         YES
# 3                       NaN         YES
# 4                       NaN         YES
# 5                     200.0         YES
# 6                      30.0          NO
# 7                      30.0          NO
# 8                      50.0          NO
# 9                       1.0         YES

# %% [markdown]
# There are multiple constraints that can be enforced on the columns like PRIMARY KEY, UNIQUE, NOT NULL. The Foreign Key and Check Constraints have to understood throughly. One thing I came to know is that there can multiple column with UNIQUE constraints, and **Foreign Key can be defined agains the column that is UNIQUE**

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
                FROM information_schema.table_constraints
                WHERE table_name = 'users'""")
# Out:
#   table_catalog table_name constraint_type        constraint_name
# 0     retail_db      users           CHECK  2200_16444_2_not_null
# 1     retail_db      users           CHECK  2200_16444_3_not_null
# 2     retail_db      users           CHECK  2200_16444_4_not_null

# %%
#dropping the above table to create the same table differently

queryTable("""DROP TABLE IF EXISTS users """)

# %%
queryTable("""CREATE TABLE users ( 
    user_id INT,
    user_first_name VARCHAR(30) NOT NULL,
    user_last_name VARCHAR(30) NOT NULL,
    user_email_id VARCHAR(50) NOT NULL,
    user_email_validated BOOLEAN,
    user_password VARCHAR(200),
    user_role VARCHAR(1),
    is_active BOOLEAN,
    created_dt DATE DEFAULT CURRENT_DATE
);""")

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
            FROM information_schema.table_constraints
            WHERE table_name = 'users'""")
# Out:
#   table_catalog table_name constraint_type        constraint_name
# 0     retail_db      users           CHECK  2200_16457_2_not_null
# 1     retail_db      users           CHECK  2200_16457_3_not_null
# 2     retail_db      users           CHECK  2200_16457_4_not_null

# %%
queryTable("""ALTER TABLE users ADD PRIMARY KEY (user_id) """)

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
            FROM information_schema.table_constraints
            WHERE table_name = 'users'""")
# Out:
#   table_catalog table_name constraint_type        constraint_name
# 0     retail_db      users     PRIMARY KEY             users_pkey
# 1     retail_db      users           CHECK  2200_16457_1_not_null
# 2     retail_db      users           CHECK  2200_16457_2_not_null
# 3     retail_db      users           CHECK  2200_16457_3_not_null
# 4     retail_db      users           CHECK  2200_16457_4_not_null

# %%
queryTable("""ALTER TABLE users DROP CONSTRAINT PRIMARY KEY (user_id) """)
# Out:
# syntax error at or near "PRIMARY"
# LINE 1: ALTER TABLE users DROP CONSTRAINT PRIMARY KEY (user_id)
#                                           ^

# %%
queryTable("""ALTER TABLE users ADD UNIQUE (user_email_id) """)

# %%
queryTable("""ALTER TABLE users
            ALTER COLUMN user_email_validated SET NOT NULL,
            ALTER COLUMN user_role SET NOT NULL""")

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
            FROM information_schema.table_constraints
            WHERE table_name = 'users'""")
# Out:
#   table_catalog table_name constraint_type          constraint_name
# 0     retail_db      users     PRIMARY KEY               users_pkey
# 1     retail_db      users          UNIQUE  users_user_email_id_key
# 2     retail_db      users           CHECK    2200_16457_1_not_null
# 3     retail_db      users           CHECK    2200_16457_2_not_null
# 4     retail_db      users           CHECK    2200_16457_3_not_null
# 5     retail_db      users           CHECK    2200_16457_4_not_null
# 6     retail_db      users           CHECK    2200_16457_5_not_null
# 7     retail_db      users           CHECK    2200_16457_7_not_null

# %%
#practice table
queryTable("""CREATE TABLE user_logins(
                user_login_id SERIAL PRIMARY KEY,
                user_id INT,
                user_login_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                user_ip_addr VARCHAR(20))""")

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
            FROM information_schema.table_constraints
            WHERE table_name = 'user_logins'""")
# Out:
#   table_catalog   table_name constraint_type        constraint_name
# 0     retail_db  user_logins     PRIMARY KEY       user_logins_pkey
# 1     retail_db  user_logins           CHECK  2200_16466_1_not_null

# %%
queryTable("""ALTER TABLE user_logins ADD FOREIGN KEY (user_id) REFERENCES users(user_id)""")

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
            FROM information_schema.table_constraints
            WHERE table_name = 'user_logins'""")
# Out:
#   table_catalog   table_name constraint_type           constraint_name
# 0     retail_db  user_logins     PRIMARY KEY          user_logins_pkey
# 1     retail_db  user_logins     FOREIGN KEY  user_logins_user_id_fkey
# 2     retail_db  user_logins           CHECK     2200_16466_1_not_null

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
            FROM information_ schema.table_constraints
            WHERE table_name = 'users'""")
# Out:
#   table_catalog table_name constraint_type          constraint_name
# 0     retail_db      users     PRIMARY KEY               users_pkey
# 1     retail_db      users          UNIQUE  users_user_email_id_key
# 2     retail_db      users           CHECK    2200_16457_1_not_null
# 3     retail_db      users           CHECK    2200_16457_2_not_null
# 4     retail_db      users           CHECK    2200_16457_3_not_null
# 5     retail_db      users           CHECK    2200_16457_4_not_null
# 6     retail_db      users           CHECK    2200_16457_5_not_null
# 7     retail_db      users           CHECK    2200_16457_7_not_null

# %%
queryTable("""CREATE INDEX order_items_oid_idx ON order_items(order_item_order_id)""")

# %%
queryBase("""SELECT table_catalog, table_name, constraint_type, constraint_name
            FROM information_schema.table_constraints
            WHERE table_name = 'order_items'""")
# Out:
#   table_catalog   table_name constraint_type        constraint_name
# 0     retail_db  order_items     PRIMARY KEY       order_items_pkey
# 1     retail_db  order_items           CHECK  2200_16416_1_not_null
# 2     retail_db  order_items           CHECK  2200_16416_2_not_null
# 3     retail_db  order_items           CHECK  2200_16416_3_not_null
# 4     retail_db  order_items           CHECK  2200_16416_4_not_null
# 5     retail_db  order_items           CHECK  2200_16416_5_not_null
# 6     retail_db  order_items           CHECK  2200_16416_6_not_null

# %%
queryBase("""SELECT *
            FROM pg_catalog.pg_indexes
            WHERE schemaname = 'public'
            AND tablename = 'users'""")
# Out:
#   schemaname tablename                indexname tablespace  \
# 0     public     users               users_pkey       None
# 1     public     users  users_user_email_id_key       None
#
#                                             indexdef
# 0  CREATE UNIQUE INDEX users_pkey ON public.users...
# 1  CREATE UNIQUE INDEX users_user_email_id_key ON...

# %%
queryTable("""DROP TABLE IF EXISTS users cascade""")

# %%
queryTable("""CREATE TABLE users ( 
    user_id INT,
    user_first_name VARCHAR(30) NOT NULL,
    user_last_name VARCHAR(30) NOT NULL,
    user_email_id VARCHAR(50) NOT NULL,
    user_email_validated BOOLEAN,
    user_password VARCHAR(200),
    user_role VARCHAR(1),
    is_active BOOLEAN,
    created_dt DATE DEFAULT CURRENT_DATE
);""")

# %%
queryBase("""SELECT *
                FROM pg_catalog.pg_indexes
                WHERE schemaname = 'public'
                AND tablename = 'users'""")
# Out:
# Empty DataFrame
# Columns: [schemaname, tablename, indexname, tablespace, indexdef]
# Index: []

# %%
queryTable("""ALTER TABLE users
            ALTER COLUMN user_id SET DEFAULT nextval('users_user_id_seq'),
            ADD PRIMARY KEY (user_id)""")

# %%
queryBase("""SELECT *
                FROM pg_catalog.pg_indexes
                WHERE schemaname = 'public'
                AND tablename = 'users'""")
# Out:
#   schemaname tablename   indexname tablespace  \
# 0     public     users  users_pkey       None
#
#                                             indexdef
# 0  CREATE UNIQUE INDEX users_pkey ON public.users...

# %%
queryBase("""SELECT tc.table_catalog,
    tc.table_name, 
    tc.constraint_name,
    pi.indexname
FROM information_schema.table_constraints tc JOIN pg_catalog.pg_indexes pi
    ON tc.constraint_name = pi.indexname
WHERE tc.table_schema = 'public'
    AND tc.table_name = 'users'
    AND tc.constraint_type = 'PRIMARY KEY'""")
# Out:
#   table_catalog table_name constraint_name   indexname
# 0     retail_db      users      users_pkey  users_pkey

# %%
queryTable("""ALTER TABLE users ADD UNIQUE (user_email_id) """)

# %%
queryBase("""SELECT *
                FROM pg_catalog.pg_indexes 
                WHERE schemaname = 'public'
                AND tablename = 'users'""")
# Out:
#   schemaname tablename                indexname tablespace  \
# 0     public     users               users_pkey       None
# 1     public     users  users_user_email_id_key       None
#
#                                             indexdef
# 0  CREATE UNIQUE INDEX users_pkey ON public.users...
# 1  CREATE UNIQUE INDEX users_user_email_id_key ON...

# %% [markdown]
# Surrogate Keys are columns that are created by the data engineer when the given table doesn't have any relevant keys

# %%
queryTable("""DROP SEQUENCE IF EXISTS test_seq""")

# %%
queryTable("""CREATE SEQUENCE test_seq
                START WITH 101
                MINVALUE 101
                MAXVALUE 1000
                INCREMENT BY 100""")
# Out:
# relation "test_seq" already exists

# %%
queryTable("""SELECT currval('test_seq')""")

# %%
queryTable("""SELECT nextval('test_seq')""")

# %%
queryBase("""SELECT currval('test_seq')""")
# Out:
# ---------------------------------------------------------------------------
# ObjectNotInPrerequisiteState              Traceback (most recent call last)
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# ObjectNotInPrerequisiteState: currval of sequence "test_seq" is not yet defined in this session
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In [84], line 1
# ----> 1 queryBase("""SELECT currval('test_seq')""")
#
# Cell In [24], line 27, in queryBase(query)
#      26 def queryBase(query):
# ---> 27     requiredTable = pd.read_sql(query,con=credentials)
#      28     return requiredTable
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:1560, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1512 """
#    1513 Read SQL query into a DataFrame.
#    1514
#    (...)
#    1556
#    1557 """
#    1558 args = _convert_params(sql, params)
# -> 1560 result = self.execute(*args)
#    1561 columns = result.keys()
#    1563 if chunksize is not None:
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:1405, in SQLDatabase.execute(self, *args, **kwargs)
#    1403 def execute(self, *args, **kwargs):
#    1404     """Simple passthrough to SQLAlchemy connectable"""
# -> 1405     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3257, in Engine.execute(self, statement, *multiparams, **params)
#    3239 """Executes the given construct and returns a
#    3240 :class:`_engine.CursorResult`.
#    3241
#    (...)
#    3254
#    3255 """
#    3256 connection = self.connect(close_with_result=True)
# -> 3257 return connection.execute(statement, *multiparams, **params)
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1365, in Connection.execute(self, statement, *multiparams, **params)
#    1356 if isinstance(statement, util.string_types):
#    1357     util.warn_deprecated_20(
#    1358         "Passing a string to Connection.execute() is "
#    1359         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1362         "driver-level SQL string."
#    1363     )
# -> 1365     return self._exec_driver_sql(
#    1366         statement,
#    1367         multiparams,
#    1368         params,
#    1369         _EMPTY_EXECUTION_OPTS,
#    1370         future=False,
#    1371     )
#    1373 try:
#    1374     meth = statement._execute_on_connection
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1669, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1659         (
#    1660             statement,
#    1661             distilled_params,
#    (...)
#    1665             statement, distilled_parameters, execution_options
#    1666         )
#    1668 dialect = self.dialect
# -> 1669 ret = self._execute_context(
#    1670     dialect,
#    1671     dialect.execution_ctx_cls._init_statement,
#    1672     statement,
#    1673     distilled_parameters,
#    1674     execution_options,
#    1675     statement,
#    1676     distilled_parameters,
#    1677 )
#    1679 if not future:
#    1680     if self._has_events or self.engine._has_events:
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2124, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2122     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2123 elif should_wrap:
# -> 2124     util.raise_(
#    2125         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126     )
#    2127 else:
#    2128     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1898                 break
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#    1905     self.dispatch.after_cursor_execute(
#    1906         self,
#    1907         cursor,
#    (...)
#    1911         context.executemany,
#    1912     )
#
# File /usr/lib/python3.10/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# OperationalError: (psycopg2.errors.ObjectNotInPrerequisiteState) currval of sequence "test_seq" is not yet defined in this session
#
# [SQL: SELECT currval('test_seq')]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
queryTable("""
    DROP TABLE IF EXISTS users;
    CREATE TABLE users ( 
    user_id SERIAL PRIMARY KEY,
    user_first_name VARCHAR(30) NOT NULL,
    user_last_name VARCHAR(30) NOT NULL,
    user_email_id VARCHAR(50) NOT NULL,
    user_email_validated BOOLEAN,
    user_password VARCHAR(200),
    user_role VARCHAR(1),
    is_active BOOLEAN,
    created_dt DATE DEFAULT CURRENT_DATE
);""")

# %%
queryBase("""SELECT *
                FROM pg_catalog.pg_indexes 
                WHERE schemaname = 'public'
                AND tablename = 'users'""")
# Out:
#   schemaname tablename   indexname tablespace  \
# 0     public     users  users_pkey       None
#
#                                             indexdef
# 0  CREATE UNIQUE INDEX users_pkey ON public.users...

# %%
queryBase("""SELECT *
                FROM information_schema.sequences""")
# Out:
#   sequence_catalog sequence_schema                  sequence_name data_type  \
# 0        retail_db          public              users_user_id_seq    bigint
# 1        retail_db          public  user_logins_user_login_id_seq   integer
# 2        retail_db          public                       test_seq    bigint
# 3        retail_db          public             users_user_id_seq1   integer
#
#    numeric_precision  numeric_precision_radix  numeric_scale start_value  \
# 0                 64                        2              0           1
# 1                 32                        2              0           1
# 2                 64                        2              0         101
# 3                 32                        2              0           1
#
#   minimum_value        maximum_value increment cycle_option
# 0             1  9223372036854775807         1           NO
# 1             1           2147483647         1           NO
# 2           101                 1000       100           NO
# 3             1           2147483647         1           NO
